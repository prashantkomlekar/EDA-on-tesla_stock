# %% [markdown]
# # EDA on Tesla stock data analysis

# %% [markdown]
# # Stwp 1. Importing the libraries
#  we always initialize by importing the important libraries neededd to performing EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from pandas.plotting import table

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2 Creating &  Reading the data

# %%
# load the dataset
df = pd.read_csv("TSLA.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035004   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#  convert the data column to datetime objects
df["Date"] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# disable the scientific notation to understand figures figures better
pd.set_option('display.float_format',lambda x: '%2f' % x)

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2010-06-29  19.000000  25.000000  17.540001  23.889999  23.889999
# 1    2010-06-30  25.790001  30.420000  23.299999  23.830000  23.830000
# 2    2010-07-01  25.000000  25.920000  20.270000  21.959999  21.959999
# 3    2010-07-02  23.000000  23.100000  18.709999  19.200001  19.200001
# 4    2010-07-06  20.000000  20.000000  15.830000  16.110001  16.110001
# ...         ...        ...        ...        ...        ...        ...
# 2411 2020-01-28 568.489990 576.809998 558.080017 566.900024 566.900024
# 2412 2020-01-29 575.690002 589.799988 567.429993 580.989990 580.989990
# 2413 2020-01-30 632.419983 650.880005 618.000000 640.809998 640.809998
# 2414 2020-01-31 640.000000 653.000000 632.520020 650.570007 650.570007
# 2415 2020-02-03 673.690002 786.140015 673.520020 780.000000 780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
df.describe(include='all')
# Out:
#                        Date        Open        High         Low       Close  \
# count                  2416 2416.000000 2416.000000 2416.000000 2416.000000
# unique                 2416         NaN         NaN         NaN         NaN
# top     2010-06-29 00:00:00         NaN         NaN         NaN         NaN
# freq                      1         NaN         NaN         NaN         NaN
# first   2010-06-29 00:00:00         NaN         NaN         NaN         NaN
# last    2020-02-03 00:00:00         NaN         NaN         NaN         NaN
# mean                    NaN  186.271147  189.578224  182.916639  186.403651
# std                     NaN  118.740163  120.892329  116.857591  119.136020
# min                     NaN   16.139999   16.629999   14.980000   15.800000
# 25%                     NaN   34.342498   34.897501   33.587501   34.400002
# 50%                     NaN  213.035004  216.745002  208.870002  212.960007
# 75%                     NaN  266.450012  270.927513  262.102501  266.774994
# max                     NaN  673.690002  786.140015  673.520020  780.000000
#
#          Adj Close          Volume
# count  2416.000000     2416.000000
# unique         NaN             NaN
# top            NaN             NaN
# freq           NaN             NaN
# first          NaN             NaN
# last           NaN             NaN
# mean    186.403651  5572721.688742
# std     119.136020  4987809.151888
# min      15.800000   118500.000000
# 25%      34.400002  1899275.000000
# 50%     212.960007  4578400.000000
# 75%     266.774994  7361150.000000
# max     780.000000 47065000.000000

# %% [markdown]
# # check if there are missing values. if yes,handle them

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# to check if there are any special character in place of values
for i in df.columns:
    print({i:df[i].unique()})
# Out:
# {'Date': array(['2010-06-29T00:00:00.000000000', '2010-06-30T00:00:00.000000000',
#        '2010-07-01T00:00:00.000000000', ...,
#        '2020-01-30T00:00:00.000000000', '2020-01-31T00:00:00.000000000',
#        '2020-02-03T00:00:00.000000000'], dtype='datetime64[ns]')}
# {'Open': array([ 19.      ,  25.790001,  25.      , ..., 632.419983, 640.      ,
#        673.690002])}
# {'High': array([ 25.      ,  30.42    ,  25.92    , ..., 650.880005, 653.      ,
#        786.140015])}
# {'Low': array([ 17.540001,  23.299999,  20.27    , ..., 618.      , 632.52002 ,
#        673.52002 ])}
# {'Close': array([ 23.889999,  23.83    ,  21.959999, ..., 640.809998, 650.570007,
#        780.      ])}
# {'Adj Close': array([ 23.889999,  23.83    ,  21.959999, ..., 640.809998, 650.570007,
#        780.      ])}
# {'Volume': array([18766300, 17187100,  8218800, ..., 29005700, 15719300, 47065000],
#       dtype=int64)}

# %% [markdown]
# # Step5 to visualize the given data imfo graphical format

# %%
# creating a list for numerical columns that are to be visualized 
column_list = ['Open','High','Low','Close','Adj Close','Volume']

df.plot(x = "Date", y = column_list, subplots = True,layout=(3,2),
       figsize = (15,15),
       title = "Stock Value Trend from 2010 - 2020", rot = 90)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %%
column_list = ['Open','High','Low','Close','Adj Close','Volume']

df.plot(x = "Date", y = column_list, 
       figsize = (15,15),
       title = "Stock Value Trend from 2010 - 2020", rot = 90)
# Out:
# <AxesSubplot:title={'center':'Stock Value Trend from 2010 - 2020'}, xlabel='Date'>

# %%
 # use the column_list : list initialized above in the following steps
fig , ax = plt.subplots(len(column_list), figsize = (15,10))

 for i, col_list in enumerate(column_list):
        sns.distplot(df[col_list], hist = True, ax = ax[i])
        ax[i].set_title("Frequency Distribution of" + " " + col_list, fontsize = 10)
        ax[i].set_xlabel (col_list, fontsize = 8)
        ax[i].set_ylabel("Distribution Value", fontsize = 8)
        fig.tight_layout (pad = 1.1) 
        # this will help to provide to spaces btw the plots
        ax[i].grid('on') # use to unable the grid lines in the plots.

# %% [markdown]
# # 1. if the values are perfectly distributed than a bell shaped normalized curve will be formed
#  # 2. if the values are showing skewness towards the left or right then the  data consists of outliers

# %%
# Generting whisker plots to detect the presence of any outlier
fig, ax= plt.subplots(len(column_list), figsize=(10,20))


for i ,col_list in enumerate(column_list):
        sns.boxplot(df[col_list], ax = ax[i], palette = "winter", orient = 'h')
        ax[i].set_title("Whisker(Box) Plot for Outlier Detection on" + " " + 
                        col_list, fontsize = 10)
        ax[i].set_ylabel(col_list,fontsize=8)
        fig.tight_layout(pad=1.1)

# %%
# Since the data is a time series data, we should be able to predict the future through 
#forecasting techniques

# Decomposing the time series year-wise and month-wise to analyse it further
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['WeekDay'] = df['Date'].dt.weekday

# Firstly plotting the data year-wise to see the duration of when it hiked and dipped
fig, ax = plt.subplots(len(column_list), figsize = (10, 20))

# Grouped the data by year & its plot
for i, col_list in enumerate(column_list):
    df.groupby('Year')[col_list].plot(ax = ax[i], legend = True)
    ax[i].set_title("Stock Price Movement Grouped by Year on" + " " + col_list, fontsize = 10)
    ax[i].set_ylabel(col_list + " " + "Price", fontsize = 8)
    fig.tight_layout(pad = 1.1)
    ax[i].yaxis.grid(True) # enabling grid lines on Y axis.

# %%
# Visualzing only the total volume of stocks traded grouped year-wise
check = df.groupby('Year')['Volume'].sum()
plt.figure(figsize = (30, 5))
ax1 = plt.subplot(121)
check.plot(y = "Volume", legend = True, fontsize = 12, 
           title = "Total Volume of Stocks Traded Year-wise from 2010 - 2020", 
           rot = 90, color = "green")

ax1.set_ylabel("Total Stock Volumes")
ax1.grid(True)

# %%
# Visualzing only the total volume of stocks traded grouped month-wise
check = df.groupby('Month')['Volume'].sum()
plt.figure(figsize = (30, 4))
ax1 = plt.subplot(121)
check.plot(y = "Volume", legend = False, fontsize = 12, sharex = False, 
           title = "Total Volume of Stocks Traded Month-wise from 2010 - 2020", 
           rot = 90, color = "blue")

ax1.set_ylabel("Total Stock Volumes")
ax1.yaxis.grid(True)

# %%
#Analysing it based on Year
# Analysing it based on Year
for i, col_list in enumerate(column_list):
    var = df.groupby('WeekDay')[col_list].sum()
    
# Converting the variable into a pandas dataframe
var = pd.DataFrame(var)

# %%
var
# Out:
#              Volume
# WeekDay
# 0        2578390800
# 1        2788784800
# 2        2706179000
# 3        2786937200
# 4        2603403800

# %%
# Visualzing only the total volume of stocks traded grouped weekday-wise      
check = df.groupby('WeekDay')['Volume'].sum()
plt.figure(figsize = (30, 4))
ax1 = plt.subplot(121)
check.plot(y = "Volume",legend = True, fontsize = 12,title = "Total Volume of Stocks Traded WeekDay-wise from 2010 - 2020", rot = 90, color = "red")

ax1.set_ylabel("Total Stock Volumes")
ax1.yaxis.grid(True)

# %%
 # Analysing it based on Year
for i, col_list in enumerate(column_list):
    var = df.groupby('Year')[col_list].sum()
    
# Converting the variable into a pandas dataframe
var = pd.DataFrame(var)

# %%
var
# Out:
#           Volume
# Year
# 2010   205369100
# 2011   325235100
# 2012   307449000
# 2013  2118745900
# 2014  1742321300
# 2015  1088217800
# 2016  1162361700
# 2017  1590031400
# 2018  2161638800
# 2019  2308042000
# 2020   454283500

# %%
# Plotting to understand the trend using pie charts
plt.figure(figsize = (16, 7))
ax1 = plt.subplot(121)
var.plot(kind = "pie", y = "Volume", legend = False, fontsize = 12,autopct="%1.2f%%",
         title = "Time Series Influence on Total Volume Trade by Year", ax = ax1)

# Plotting the table to identify numbers
ax2 = plt.subplot(122)
plt.axis('off') # Since we are plotting the table
tbl = table(ax2, var, loc = 'center')

tbl.set_fontsize(12)
plt.show()

# %% [markdown]
# ## The highest total volume trade was in 2019
